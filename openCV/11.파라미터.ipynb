# %%
from IPython.display import display, HTML
display(HTML("<style>div.container { width:100% !important; }</style>"))
# Out:
# <style>div.container { width:100% !important; }</style>

# %%
def lastName_and_firstName(*args):
    for arg in args:
        print("%s %s" % (arg[0],arg[1:3]),end=" ")
    print("\n")
    print(type(args))

# %%
lastName_and_firstName("홍길동")
lastName_and_firstName("홍길동","이순신")
lastName_and_firstName("홍길동","이순신","진라")
lastName_and_firstName("홍길동","이순신","진라","진시황")
# Out:
# 홍 길동
#
# <class 'tuple'>
# 홍 길동 이 순신
#
# <class 'tuple'>
# 홍 길동 이 순신 진 라
#
# <class 'tuple'>
# 홍 길동 이 순신 진 라 진 시황
#
# <class 'tuple'>

# %%
a1 = "홍길동"
a2 = "이순신"
a3 = "진라미"
a4 = "진시황"


lastName_and_firstName(a1)
lastName_and_firstName(a1,a2)
lastName_and_firstName(a1,a2,a3)
lastName_and_firstName(a1,a2,a3,a4)
# Out:
# 홍 길동
#
# <class 'tuple'>
# 홍 길동 이 순신
#
# <class 'tuple'>
# 홍 길동 이 순신 진 라미
#
# <class 'tuple'>
# 홍 길동 이 순신 진 라미 진 시황
#
# <class 'tuple'>

# %%
def lastName_and_firstName(*args):
    for arg in args:
        print("{} {}".format  (arg[0],arg[1:3]),end=" ")
    print("\n")
    print(type(args))

# %%
lastName_and_firstName(a1,a2,a3,a4)
# Out:
# 홍 길동 이 순신 진 라미 진 시황
#
# <class 'tuple'>

# %%
블로그1 = "첫번째 블로그 ~"
블로그2 = "두번 쨰 블로그"
블로그3 = "세번째 블로그"

# %%
def blog_msg(*blogs):
    for post in blogs:
        print("{}".format(post))
    print("\n")

# %%
blog_msg(블로그1,블로그2,블로그3)
# Out:
# 첫번째 블로그 ~
# 두번 쨰 블로그
# 세번째 블로그

# %%
블로그1 = "첫번째 블로그 ~"
블로그2 = "두번 쨰 블로그"
블로그3 = "세번째 블로그"

제목 = "인공지능 학습센터"

# %%
def blog_msg2(name,*blogs):
    print("{}".format(name))
    for post in blogs:
        print("제목{} {}".format(name,post))
    print("\n")

# %%
blog_msg2(제목,블로그1,블로그2,블로그3)
# Out:
# 인공지능 학습센터
# 제목인공지능 학습센터 첫번째 블로그 ~
# 제목인공지능 학습센터 두번 쨰 블로그
# 제목인공지능 학습센터 세번째 블로그

# %%
def blog_msg3(*blogs,name):
    print("{}".format(name))
    for post in blogs:
        print("제목{} {}".format(name,post))
    print("\n")

# %%
blog_msg3(블로그1,제목)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [87], line 1
# ----> 1 blog_msg3(블로그1,제목)
#
# TypeError: blog_msg3() missing 1 required keyword-only argument: 'name'

# %%
def blog_benefits(**blogs_benefits):
    print(blogs_benefits)
    for name,benfits in blogs_benefits.items():
        print("{} 블로그 수익은{}입니다".format(name,benfits))
    print("\n")

# %%
blog_benefits(홍길동=10,이순신=20,강감찬 =30)
# Out:
# {'홍길동블로그': 10, '이순신': 20, '강감찬': 30}
# 홍길동블로그 블로그 수익은10입니다
# 이순신 블로그 수익은20입니다
# 강감찬 블로그 수익은30입니다

# %%
title = "인공지능 학습센터"

blog1 = "첫번째 블로그 ~"
blog2 = "두번 쨰 블로그"
blog3 = "세번째 블로그"

# %%
def blog_information(title,*blogs,**blogs_benefits):
    print("블로그 제목:{}".format(title))
    for post in blogs:
        print(" {}".format(post))
    print(blogs_benefits)
    for name,benfits in blogs_benefits.items():
        print("{} 블로그 수익은{}입니다".format(name,benfits))

# %%
blog_information(title,blog1,blog2,blog3,홍길동=10,이순신=20,강감찬=30)
# Out:
# 블로그 제목:인공지능 학습센터
#  첫번째 블로그 ~
#  두번 쨰 블로그
#  세번째 블로그
# {'홍길동': 10, '이순신': 20, '강감찬': 30}
# 홍길동 블로그 수익은10입니다
# 이순신 블로그 수익은20입니다
# 강감찬 블로그 수익은30입니다

# %% [markdown]
# # 이미지를 서로 합칠 때 가중치를 두어 합치는 방법입니다

# %%
import cv2 
import numpy as np

img1 = cv2.imread('images/flower1.jpg')
img2 = cv2.imread('images/flower2.jpg')

def nothing(x) :
    pass

cv2.namedWindow('image')
cv2.createTrackbar('W','image',0,100,nothing)

while True:
    w = cv2.getTrackbarPos('W', 'image')
    dst = cv2.addWeighted(img1,float(100-w)*0.01,img2,float(w)*0.01,0)

    cv2.imshow('dst',dst)
    if cv2.waitKey(1) &0xFF == 27:
        break

cv2.destroyAllWindows()

# %%
import cv2 
import numpy as np

def weighted_blending(img1,img2,img1_weight=0.5):
    output = np.zeros(img1.shape,dtype=np.uint8)
    height,width = img1.shape[0:2]
    if len(img1.shape)==2:
        for y in range(height):
            for x in range(width):
                output[y,x] = int(img1[y,x] *img1_weight + img2[y,x]*(1-img1_weight))
    
    elif  len(img1.shape)==3:
        for y in range(height):
            for x in rnage(width):
                blended = img1[y,x] *img1_weight + img2[y,x] *(1-img1_weight)
                output[y,x] = blended.astype(np.uint8)
    return output

# %% [markdown]
# cv2.seamlessClone()

# %%
import cv2
import numpy as np

src = cv2.imread("./images/airplane2.jpg")
dst = cv2.imread("./images/red_sky.jpg")
src_mask = np.zeros(src.shape,src.dtype)
poly = np.array([[0,40],[150,60],[203,56],[200,100],[88,103],[1,75]],np.int32)

cv2.fillPoly(src_mask,[poly],(255,255,255))
center = (600,150)
output = cv2.seamlessClone(src,dst,src_mask,center,cv2.NORMAL_CLONE)

cv2.imshow('Output', output)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 이진화

# %%
import cv2
import numpy as np

def two_tone(img,threshold=128):
    output = (img > threshold)*255
    return output.astype(np.uint8)

# %%
img = cv2.imread("./images/lena.jpg",0)
new_img = two_tone(img,threshold=120)
cv2.imwrite("./images/lena_bin.jpg",new_img)
cv2.imshow('img',new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('images/gradation.png',0)
ret, thresh1 = cv2.threshold(img,127,255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img,127,255, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img,127,255, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img,127,255, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img,127,255, cv2.THRESH_TOZERO_INV)
ret, thresh6 = cv2.threshold(img,-1,255, cv2.THRESH_OTSU)
ret, thresh7 = cv2.threshold(img,-1,255, cv2.THRESH_TRUNC | cv2.THRESH_OTSU)
titles = ['Original','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV','OTSU','TRUNC OTSU']
images = [img,thresh1,thresh2,thresh3,thresh4,thresh5,thresh6,thresh7]
for i in range(8):
    plt.subplot(2,4,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %% [markdown]
# # adaptiveThreshold(적응 임계처림)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img_gray = cv2.imread('images/house.jpg', 0)
_, img_bin = cv2.threshold(img_gray, 127, 255, cv2.THRESH_BINARY)
adt_mean = cv2.adaptiveThreshold(img_gray, 255,
                                 cv2.ADAPTIVE_THRESH_MEAN_C,
                                 cv2.THRESH_BINARY, 15, 0)
adt_gaus = cv2.adaptiveThreshold(img_gray, 255,
                                 cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                 cv2.THRESH_BINARY, 15, 0)
titles = ['Gray', 'Global', 'Mean', 'Gaussian']
images = [img_gray, img_bin, adt_mean, adt_gaus]
plt.figure(figsize=(8,6))
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()
